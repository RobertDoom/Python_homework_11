# %%
import pandas as pd

# %%
df = pd.read_csv('train (2).csv')

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns

# %%
df.groupby(['Sex', 'Pclass']).agg({'Survived': 'sum'})
# Out:
#                Survived
# Sex    Pclass
# female 1             91
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
def sum_str(str):
    sum = 0
    for i in range(len(str)):
        sum += int(str[i])
    return sum

# %%
def is_lucky_ticket(ticket):
    ticket_part = ticket.split()
    for i in ticket_part:
        if i.isdigit() and len(i) == 6:
            ticket = i
            if sum_str(ticket[:3]) == sum_str(ticket[3:]):
                return ticket
        return None

# %%
def find_lucky(data):
    tickets=[]
    for ticket in enumerate(data.Ticket):
        
        if ticket_ := is_lucky_ticket(ticket[1]):
            tickets.append(ticket[0])
    return pd.DataFrame(data, index = tickets)

# %%
find_lucky(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 16            17         0       3
# 25            26         1       3
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 171          172         0       3
# 175          176         0       3
# 182          183         0       3
# 184          185         1       3
# 198          199         1       3
# 233          234         1       3
# 261          262         1       3
# 278          279         0       3
# 281          282         0       3
# 328          329         1       3
# 343          344         0       2
# 388          389         0       3
# 463          464         0       2
# 499          500         0       3
# 536          537         0       1
# 548          549         0       3
# 631          632         0       3
# 767          768         0       3
# 787          788         0       3
# 844          845         0       3
# ...

# %%
find_lucky(df).Survived.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
find_lucky(df).Survived.value_counts(normalize = True).mul(100).round(2)
# Out:
# 0    74.07
# 1    25.93
# Name: Survived, dtype: float64
